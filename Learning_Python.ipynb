# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishabh380/Python-Learning/blob/main/Learning_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#this is my first python program
def hello():
  print("Hello print")

# %%
hello()
# Out:
# Hello print

# %%
#variables _ String,integer,boolean,float

#strings variables
first_name="ABC"
food = "Pizza"
email= "habx@gab.com"

print(f"Hello {first_name}") #using f strings TEXT+Variable value
print(f"you like {food}")
print(f"your email is {email}")


#integers
age=35
quantity = 3
students = 31

print(f"you are {age} years old")
print(f"you are buying {quantity} items")
print(f"your class have {students} students")


#float

price = 10.90
gpa= 4.8

print(f"price of each item is {price} dollar")
print(f"your gpa is {gpa}")



#boolean : can be True or False

is_student=False

print(f"are you a student : {is_student}")

#if statement -- if will give true result else will give false
if is_student:
  print("you are a student")
else :
  print("you are not a student")


for_sale = True

if for_sale:
  print("that item is for sale")
else:
  print("that item is not available")
# Out:
# Hello ABC
# you like Pizza
# your email is habx@gab.com
# you are 35 years old
# you are buying 3 items
# your class have 31 students
# price of each item is 10.9 dollar
# your gpa is 4.8
# are you a student : False
# you are not a student
# that item is for sale

# %%
#typecasting : process of converting a variable from one data type to another.
#str(),int(),float(),bool()


name='test'
age=25
gpa=4.8
is_student=True

age=float(age)

print(age)
print(type(age))

gpa=int(gpa)
print(gpa)
print(type(gpa))


age=str(age)
print(age)
print(type(age))


name=bool(name)

print(name)

newname=''

newname=bool(newname)
print(newname) #could be use to confirm if user has added name or not
# Out:
# 25.0
# <class 'float'>
# 4
# <class 'int'>
# 25.0
# <class 'str'>
# True
# False

# %%
#input() - use to prompt user to enter data and return as a str


name= input("what is your name?")
age = input("what is your age ?")
print(f"Hello: {name}")

print(f"age is {age}")

gpa=input("what is your gpa :")
print(f"your gpaFYI is : {gpa}")
# Out:
# what is your name?Rishabh
# what is your age ?35
# Hello: Rishabh
# age is 35
# what is your gpa :4.8
# your gpa is : 4.8
